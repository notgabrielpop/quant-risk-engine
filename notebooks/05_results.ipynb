# %% [markdown]
# # 05 — Final Results & Visualizations
#
# Compile and present final results:
# - Model comparison tables
# - Risk decomposition charts
# - Publication-quality figures for the paper

# %%
import sys
sys.path.insert(0, '../src')

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from python.utils.config import DATA_PROCESSED, REGIMES
